# %%
import io
import json
with io.open('/content/gokul.json', 'r', encoding='utf-8-sig') as outfile:  
  JSON_file=json.load(outfile)
print(JSON_file)
# Out:
# [{'B-invoicedate': '27.08.2018', 'B-product': 'Back', 'I-product': 'Case'}, {'I-address': 'Noel'}, {'B-customer': 'CARS', 'I-address': 'PLTD.'}, {'B-customer': 'Krishna', 'B-invoiceno': '#16282658099'}, {'B-customer': 'Teknowmics', 'I-address': 'Knowledge'}, {'I-address': 'Noel'}, {'I-address': 'Airport'}, {'I-address': 'Kerala'}, {'I-address': 'Chicken', 'I-product': 'Chattipathiri', 'B-invoiceno': '#16282658099'}, {'B-customer': 'Teknowmics', 'I-address': 'Knowledge'}, {'I-address': 'Noel'}, {'I-address': 'Airport'}, {'I-address': 'Kerala'}, {'I-address': 'Chicken', 'I-product': 'Chattipathiri', 'B-customer': 'Ruby', 'I-customer': 'Paul', 'B-invoiceno': '#15591562257'}, {'B-customer': '8th'}, {'I-address': 'Knowledge'}, {'I-address': 'Airport'}, {'I-address': 'Kerala'}, {'I-address': 'Chicken', 'I-product': 'Samosa', 'B-customer': '8th'}, {'I-address': 'Knowledge'}, {'I-address': 'Airport'}, {'I-address': 'Kerala'}, {'I-address': 'knowledge', 'I-product': 'Samosa', 'B-customer': 'T
# ...

# %%
import json

with open('aaa.json', 'w') as outfile:
    for entry in JSON_file:
        json.dump(entry, outfile)
        outfile.write('\n')

# %%
filepath = 'aaa.json'
metadata='{ "index": { "_index": "invoice2", "_type": "account" }}'
with open(filepath, mode="r",encoding="utf-8") as my_file:
    for line in my_file:
        print(metadata)
        print(line.rstrip("\n"))
# Out:
# { "index": { "_index": "invoice2", "_type": "account" }}
# {"B-invoicedate": "27.08.2018", "B-product": "Back", "I-product": "Case"}
# { "index": { "_index": "invoice2", "_type": "account" }}
# {"I-address": "Noel"}
# { "index": { "_index": "invoice2", "_type": "account" }}
# {"B-customer": "CARS", "I-address": "PLTD."}
# { "index": { "_index": "invoice2", "_type": "account" }}
# {"B-customer": "Krishna", "B-invoiceno": "#16282658099"}
# { "index": { "_index": "invoice2", "_type": "account" }}
# {"B-customer": "Teknowmics", "I-address": "Knowledge"}
# { "index": { "_index": "invoice2", "_type": "account" }}
# {"I-address": "Noel"}
# { "index": { "_index": "invoice2", "_type": "account" }}
# {"I-address": "Airport"}
# { "index": { "_index": "invoice2", "_type": "account" }}
# {"I-address": "Kerala"}
# { "index": { "_index": "invoice2", "_type": "account" }}
# {"I-address": "Chicken", "I-product": "Chattipathiri", "B-invoiceno": "#16282658099"}
# ...

# %%
a

# %%
import json
with open('/content/out.json', 'w',encoding = 'utf-8') as f:
  json.dump(data,)
