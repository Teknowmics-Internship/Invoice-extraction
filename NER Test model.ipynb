# %%
path1='/home/lenovo/Documents/ner advanved/'

# %%
#text extraction from image
import cv2

import os,glob

from pdf2image import convert_from_path

from os import listdir,makedirs

from os.path import isfile,join
path = path1+'inv/' # Source Folder
dstpath = path1+'gray/' # Destination Folder
try:
    makedirs(dstpath)
except:
    print ("Directory already exist, images will be written in same folder")
# Folder won't used
files = [f for f in listdir(path) if isfile(join(path,f))] 
for image in files:
    if image.endswith('.jpg'):
        
        try:
            img = cv2.imread(os.path.join(path,image))
            gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
            dstPath = join(dstpath,image)
            cv2.imwrite(dstPath,gray)
        except:
            print ("{} is not converted".format(image))
    else:
        pages=convert_from_path(path+image,500)
        for page in pages:
            page.save(dstpath+image+'.jpg', 'JPEG')
            
for fil in glob.glob("*.jpg"):
    try:
        image = cv2.imread(fil) 
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # convert to greyscale
        cv2.imwrite(os.path.join(dstpath,fil),gray_image)
    except:
        pages=convert_from_path(path+images,500)
        for page in pages:
            page.save(dstpath+images+'.jpg', 'JPEG')
# Out:
# Directory already exist, images will be written in same folder

# %%
import cv2

import os,glob

from os import listdir,makedirs

from os.path import isfile,join
path = path1+'gray/' # Source Folder
dstpath = path1+'denoised/' # Destination Folder
try:
    makedirs(dstpath)
except:
    print ("Directory already exist, images will be written in same folder")
# Folder won't used
files = [f for f in listdir(path) if isfile(join(path,f))] 
for image in files:
    try:
        img = cv2.imread(os.path.join(path,image))
        dst = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)
        dstPath = join(dstpath,image)
        cv2.imwrite(dstPath,dst)
    except:
        print ("{} is not converted".format(image))
for fil in glob.glob("*.jpg"):
    try:
        image = cv2.imread(fil) 
        den_image = cv2.fastNlMeansDenoisingColored(image,None,10,10,7,21) 
        cv2.imwrite(os.path.join(dstpath,fil),den_image)
    except:
        print('{} is not converted')
# Out:
# Directory already exist, images will be written in same folder

# %%
#text reading using PIL
for j in os.listdir(path1 + 'denoised/'):
    if j.endswith('.jpg'):
        try:
            from PIL import Image
        except ImportError:
            import Image
        import pytesseract
        text = pytesseract.image_to_string(Image.open(path1 + 'denoised/' + j))  # We'll use Pillow's Image class to open the image and pytesseract to detect the string in the image
    with open(path1+'text/'+j+'.txt', 'a') as a_writer:
        a_writer.write(text)

# %%
#test with saved model
from __future__ import unicode_literals, print_function
import pickle
import plac
import random
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding
import os
from os import listdir
import pandas as pd



output_dir1='/home/lenovo/Documents/teknowmics/model'
nlp2 = spacy.load(output_dir1)
path='/home/lenovo/Documents/teknowmics/'
for j in os.listdir(path):
    if j.endswith('.txt'):
        with open (j) as f:
            test_text = f.read()
          # print(test_text)
#     test_text = '''Hima Santhosh Ernakulam Singing  
        
        # '''
            label=[]
            text=[]
            doc = nlp2(test_text)
            print("Entities in '%s'" % test_text)
            for ent in doc.ents:
                # label = ent.label_
                # text = ent.text
                # a=print(ent.label_, ent.text)
                label.append(ent.label_)
                text.append( ent.text)
                # print(label)
                d = {'label':label,'text':text}
                df = pd.DataFrame(d,index=None)
                print(df)
                # ent.save(path1+'new/'+j+'.jpg', 'JPEG')
                df.to_csv(path+j+'.csv')
# Out:
# Entities in 'INVOICE
#
# Saffron Design
#
# 77 Namrata Bldg
# Delhi, Delhi 400077
#
# BILLTO SHIP TO INVOICE # IN-001
# Kavindra Mannan Kavindra Mannan INVOICE DATE 29/01/2019
# 27, Dif City, Gupta 264, Abdul Rehman Pout pene
# Delhi, Dethi 40003, ‘Mumbai, Bihar 40009 eo
# QUE DATE 26/04/2019
# any DESCRIPTION UNIT PRICE AMOUNT
# 1 Frontend design restructure 9,999.00 9,999.00
# 2 Custom icon package 975.00 41,950.00
# 3 Gandhi mouse pad 99.00 297.00
# Subtotal 12,246.00
# GST 12.0% 1,469.52
# TOTAL 313,715.52
# TERMS & CONDITIONS
#
# Payment is due within 15 days
#
# State Bank of India
# ‘Account Number: 12345678
# Routing Number: 09876543210'
# Entities in 'am aZO ni N Tax Invoice/Bill of Supply/Cash Memo
# wee)
#
# (Original for Recipient)
#
# Sold By: Billing Address:
# BoseWek INC Krishna Prasad
# 106 S. 54th Avenue Unit F Teknowmics knowledge solution, 8F Noel Focus,
# Denver, CO, 80239 chittetukara,, Kakkanad
# US Kakkanad, KERALA, 682037
#
# IN
# PAN No: Not-Applicable Shipping Address:
# GST Registration No: NotApplicable Krishna Prasad
#
# Krishna Prasad
#
# Teknowmics knowledge solution, 8f Noel focus,
# chittetukara,, Kakkanad
#
# VAZHAKKALA, KERALA, 682037
#
# IN
# Order Number: 406-8093012-1397160 Invoice Number: IN-921
# Order Date: 06.09.2018 Invoice Details: CO-797694665-1819
#
# Invoice Date: 06.09.2018
#
# Description Qt Tax |Tax |Tax Total
# p y Rate|Type|Amount|Amount
#
# 1 |KuGi Ultra-Thin Double Hybrid Protective Case Soft TPU Back Cover
# for Huawei Nova 3i (Blue) | BO7G92JXPN (
# Ga-Huawei-Nova-3i-tpu-blue )
#
# Shipping Charges
#
# Amount in Words:
# Four Hundred And Forty-nine only
#
# For BoseWek INC:
#
#
#
# Authorized Signatory
#
# Page 1 of 1'
#       label        text
# 0  I-vendor  Teknowmics
#        label        text
# 0   I-vendor  Teknowmics
# 1  I-address   knowledge
#        label        text
# 0   I-vendor  Teknowmics
# 1  I-address   knowledge
# 2  I-address   solution,
#        label        text
# 0   I-vendor  Teknowmics
# 1  I-address   knowledge
# 2  I-address   solution,
# 3  I-address          8F
#        label        text
# 0   I-vendor  Teknowmics
# 1  I-address   knowledge
# 2  I-address   solution,
# 3  I-address          8F
# 4  I-address        Noel
#        label        text
# 0   I-vendor  Teknowmics
# 1  I-address   knowledge
# 2  I-address   solution,
# 3  I-address          8F
# 4  I-address        Noel
# 5  I-address      Focus,
#        label        text
# 0   I-vendor  Teknowmics
# 1  I-address   knowledge
# 2  I-address   solution,
# 3  I-address          8F
# 4  I-address        Noel
# 5  I-address      Focus,
# 6  I-address   knowledge
#        label        text
# 0   I-vendor  Teknowmics
# 1  I-address   knowledge
# 2  I-address   solution,
# 3  I-address          8F
# 4  I-address        Noel
# 5  I-address      Focus,
# 6  I-address   knowledge
# 7  I-address   solution,
#        label        text
# 0   I-vendor  Teknowmics
# 1  I-address   knowledge
# 2  I-address   solution,
# 3  I-address          8F
# 4  I-address        Noel
# 5  I-address      Focus,
# 6  I-address   knowledge
# 7  I-address   solution,
# 8  I-address          8f
#        label        text
# 0   I-vendor  Teknowmics
# 1  I-address   knowledge
# 2  I-address   solution,
# 3  I-address          8F
# 4  I-address        Noel
# 5  I-address      Focus,
# 6  I-address   knowledge
# 7  I-address   solution,
# 8  I-address          8f
# 9  I-address        Noel
#         label        text
# 0    I-vendor  Teknowmics
# 1   I-address   knowledge
# 2   I-address   solution,
# 3   I-address          8F
# 4   I-address        Noel
# 5   I-address      Focus,
# 6   I-address   knowledge
# 7   I-address   solution,
# 8   I-address          8f
# 9   I-address        Noel
# 10  I-address      focus,
#         label        text
# 0    I-vendor  Teknowmics
# 1   I-address   knowledge
# 2   I-address   solution,
# 3   I-address          8F
# 4   I-address        Noel
# 5   I-address      Focus,
# 6   I-address   knowledge
# 7   I-address   solution,
# 8   I-address          8f
# 9   I-address        Noel
# 10  I-address      focus,
# 11  I-product        Nova
#         label        text
# 0    I-vendor  Teknowmics
# 1   I-address   knowledge
# 2   I-address   solution,
# 3   I-address          8F
# 4   I-address        Noel
# 5   I-address      Focus,
# 6   I-address   knowledge
# 7   I-address   solution,
# 8   I-address          8f
# 9   I-address        Noel
# 10  I-address      focus,
# 11  I-product        Nova
# 12  I-product          3i
# Entities in '6 swiccy
#
# Thanks for choosing Swiggy, Aiswarya! Here are your order details:
#
# Order No: #16631420183 Delivery To:
#
# Order placed at: 06/08/2018, 05:20 PM Aiswarya
#
# Order delivered at: 06/08/2018, 05:41 PM 8th floor, Teknowmics, Noel focus, B11, Seaport -
# Order Status: Delivered Airport Rd, Thuthiyoor, Chittethukara, Kakkanad,
#
# Kerala 682037, India
# Ordered from:
# Ifthar
# Opposite Infopark, Edachira, Kakkanada, Kochi
#
# Item Name Quantity Price
# Unnakkaya 2 X 30
# Kaipola 4 = 100
# Erachi Pathiri 3 = 45
#
# Item Total: ~ 175
#
# GST: 8.75
#
# Delivery Charges: x 0
#
# Discount Applied (BINGE50O): -% 91.88
# Grand Total: X92
#
# Disclaimer: This is an acknowledgement of Delivery of the Order and not an actual invoice. Details mentioned above including
# the menu prices and taxes (as applicable) are as provided by the Restaurant to Swiggy. Responsibility of charging (or not
# charging) taxes lies with the Restaurant and Swiggy disclaims any liability that may arise in this respect.'
#       label text
# 0  B-vendor  8th
#        label    text
# 0   B-vendor     8th
# 1  I-address  floor,
#        label    text
# 0   B-vendor     8th
# 1  I-address  floor,
# 2  I-address    Noel
#        label    text
# 0   B-vendor     8th
# 1  I-address  floor,
# 2  I-address    Noel
# 3  I-address  focus,
#        label    text
# 0   B-vendor     8th
# 1  I-address  floor,
# 2  I-address    Noel
# 3  I-address  focus,
# 4  I-address     Rd,
#        label    text
# 0   B-vendor     8th
# 1  I-address  floor,
# 2  I-address    Noel
# 3  I-address  focus,
# 4  I-address     Rd,
# 5  I-address  Kerala
#        label     text
# 0   B-vendor      8th
# 1  I-address   floor,
# 2  I-address     Noel
# 3  I-address   focus,
# 4  I-address      Rd,
# 5  I-address   Kerala
# 6  I-address  682037,
#        label     text
# 0   B-vendor      8th
# 1  I-address   floor,
# 2  I-address     Noel
# 3  I-address   focus,
# 4  I-address      Rd,
# 5  I-address   Kerala
# 6  I-address  682037,
# 7  I-product  Pathiri
# Entities in 'Saffisn Design
#
# 77 Namrata Bldg
# Delhi, Dethi 400077
#
# Bill To Ship To. Invoice # 1N-001
# Panchika Randhawa Kavindra Mannan Invoice Date 29/01/2019
# 27, DifCity, Central 264, Abdul Rehman. ee piseate
# Delhi, Dethi 40003 ‘Mumbai, Bihar 40009 : om
# Due Date 26/04/2019
# Cy Deer) aa) Pts
# 1 Frontend design restructure 9,999.00 9,999.00
# 2 Custom icon package 975.00 1,950.00,
# 3 Gandhi mouse pad 99.00 297.00
# Subtotal 12,246.00
# VAT 6.0% 734.76
# Invoice Total 12,980.76
#
#
#
#
#
# Terms & Conditions
# Payment is due within 15 days
#
# State Bank of India
#
# ‘Account Number: 12345678
# Routing Number: 09876543210
#
# eee'
# Entities in 'Invoicing
# Template.com
#
# Psychology Service
#
# Assoc MAPS
#
# ACT Reg No. 200% . NSW Reg No. PSO scccoxt
# Medicare Provider No. sscccccct
#
# ABN: 2000 200% 2008 30
#
# Address
#
# Phone
#
# Email
#
# Patient Details
#
# INVOICE
#
# DATE: October 14, 2018
# INVOICE #: INV1002
# Patient #: ©1006
#
# Referrer Details
#
#
#
# Name|name-test
#
#
#
# GP Name|gpname-1
#
#
#
# Address]adde-test
#
#
#
# Provider No|Providerno#1
#
#
#
# City, P/Code|citytest, statetest, 212345
#
#
#
# Referral Date|referraldate#1
#
#
#
# Date of Birth|country-test
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# phone-test
# Item # Description Quantity | Unit Price | Line Total
# litem#1 Family Counselling 1 1,000.00 1,000.00
# litem#2 Travelling for treatment 2 200.00 400.00
# litem#3 Psychologist Standard Report 500 100.00] 50,000.00
# SUBTOTAL | 51,400.00
# GST 17.50% 8,995.00
# NOTES:
# TOTAL 60,395.00
# PAID 95.00
# TOTAL DUE 60,300.00
# "PAYMENT HISTORY
# DATE TOTAL APPLIED TYPE CHECK/MONEY ORDER NOTES
# 14/Oct/18 95.00 95.00
#
# THANK YOU FOR YOUR BUSINESS!'
# Entities in 'ABC Enterprises Pvt. Ltd.
#
# GSTIN 22AAAAA0000A1Z5
# Branch Karnatka (22)
# PAN AAAAAO000A
#
# TAX INVOICE
#
# Customer Name
#
# Kantech Solutions Private Ltd.
#
# Customer GSTIN
#
# 22BBBBB0007A1Z5
# Payment Terms Net15 Due Date
# Item HSN Qty. Rate/
# Item(z)
# Himalaya Herbal Cream 440003 10kg 1000.00
# Neem Edition
# Himalaya Herbal Cream 440003 10kg 1000.00
# Neem Edition
# Himalaya Herbal Cream 440003 10kg 1000.00
# Neem Edition
# Frieght Charges - 1no 1000.00
# Total (2)
#
# Taxable amount
# Total Tax*
#
# Invoice Total
#
# Invoice Total (In words)
#
# *Tax to be paid on Reverse Charge
#
# Notes
#
# All payments to be made in cash.
# Contact us for queries on these quotations.
#
# Thank you for your business.
#
# Billing Address
#
# Kantech Solutions Private Ltd.
#
# Ground Floor, Building 2A, 23 & 24
#
# AMR Tech Park Internal Road
#
# Hongasandra, Bengaluru
#
# Karnatka 560068
#
# 19/06/2016
#
# Discount/
# Item(2)
#
# 30.00
#
# 30.00
#
# 30.00
#
# Total = 6500.00
#
# Invoice Date
# Invoice No.
#
# Reference No.
#
# 10/05/2017
# CLR-00054
#
# Shipping Address
#
# PO-9987
#
# Kantech Solutions Private Ltd.
# Ground Floor, Building 2A, 23 & 24
# AMR Tech Park Internal Road
# Hongasandra, Bengaluru
#
# Karnatka 560068
#
# Place of Supply Karnataka (22)
#
# Taxable
# Value(z)
#
# 9700.00
#
# 9700.00
#
# 9700.00
#
# 1000.00
#
# 30100.00
#
# SGST
# z
#
# 970.00
# @10%
#
# 970.00
# @10%
#
# 970.00
# @10%
#
# 50.00
# @5%
#
# 2960.00
#
# CGST
# z
#
# 970.00
# @10%
#
# 970.00
# @10%
#
# 970.00
# @10%
#
# 50.00
# @5%
#
# 2960.00
#
# CESS
#
# 00.00
# @0%
#
# 00.00
# @0%
#
# 00.00
# @0%
#
# 00.00
# @0%
#
# 00.00
#
# Total
#
# 11640.00
#
# 11640.00
#
# 11640.00
#
# 1100.00
#
# 36020.00
#
# = 30100.00
# = 5920.00
#
# = 36020.00
#
# Thirty Six Thousand Twenty Only
#
# For ABC Enterprises Pvt. Ltd.
# (Signature)
#
# Powered by & clearTax
#
# ABC Enterprises Pvt. Ltd., Ground Floor, Building 2A, 23 & 24, AMR Tech Park Internal Road, Hongasandra, Bengaluru, Karnatka 560068
# +91-9876543210, +91-9876543210, contact@abcenterprises.in'
#         label     text
# 0  B-customer  Kantech
# Entities in 'INVOICE # IN-o01 INVOICE DATE 29/01/2019
#
# Po# 2430/2019 DUE DATE 2604/2019
#
# BILL TO SHIP TO Saffron Design
#
# Panchika Randhawa Kavindra Mannan 77 Namrata Bldg
#
# 27, Dif City, Central 264, Abdul Rehman Delhi, Deihi 400077
#
# Delhi, Dethi 40003, Mumbai, Bihar 40009
#
# CR sacs a maces ‘AMOUNT
#
# 1 Frontend design restructure 9,999.00 9,999.00
#
# 2 ‘Custom icon package 975.00 1,950.00
#
# 3 Gandhi mouse pad 99.00 297.00
#
# ‘Subtotal 12,246.00
#
# VAT 6.0% 734.76
#
# INVOICE TOTAL
#
# TERMS & CONDITIONS
# Payment is due within 15 days
#
# State Bank of India
# ‘Account Number: 12345678
# Routing Number: 09876543210
#
# %12,980.76'
# Entities in 'Saffron Design
#
# *C GOK >
#
# os
#
#
#
#
#
# 77 Namrata Bldg
# Delhi, Delhi 400077
# o>—_____-®
# Bill To Ship To Invoice Date 29/01/2019
# Panchika Randhawa Kavindra Mannan 2.0.4 2430/2019
# 27, Dif City, Central 264, Abdul Rehman
# Delhi, Delhi 40003 Mumbai, Bihar 40009 Die Dae) ev
# Invoice # \N-001
# QTY DESCRIPTION UNIT PRICE AMOUNT
# ¢ Frontend design restructure 9,999.00 9,999.00
# 2 Custom icon package 975.00 1,950.00
# 3 Gandhi mouse pad 99.00 297.00
# ‘Subtotal 12,246.00
# VAT 6.0% 734.76
# INVOICE TOTAL %12,980.76
#
#
#
#
#
#
#
# CSE" Oo
#
# Terms & Conditions
# Payment is due within 15 days
# State Bank of India
#
# Account Number: 12345678
# Routing Number: 09876543210'
# Entities in 'Nhe Bet Glad esting
# SkyGST Sdn. Bhd.
# 08-518, 8th Floor,
#
# No LJjalan Imbi,
#
# Berjaya Times Square, Kuala Lumpur 55100
# Malaysia
#
# Co. No:
# GST ID:
#
# 654072-D
# 12345/2015
#
# Phone +603 2725 0658
#
# Fax +603 2725 0659
# Mail) sales@skygst.com
# Website: www_skygst.com
#
#
#
# TAX INVOICE
#
# Bill To:
#
# ‘Supplier 1
#
# 11 rue Albert Einstein
#
# 81 Academy Avenue
#
# Champs sur Marne Kedah 8000
# Malaysia
#
# GST ID : 200004/2015
#
# Co. Reg : 45478-K
#
# Tel. . +60 10 588 458
#
# Fax . +60 10 588 559
#
#
#
#
#
# Invoice No : EXj/2014/0001
# Invoice Date 01/01/14
# Payment Term : 21 Days
# Invoice Ref. : PO/14/001
# Due Date : 2014-01-16
# Prepared By Rahman
#
#
#
#
#
# Item Description Taxes Quantity Unit Price Disc.(%) Price
# (RM) (RM)
# z *Purchase item A ™ 1.000 1000.00 0.00 1000.00
# Net Total (Excl. GST): 10000.00
# GST Taxes @ (6%) 600.00
# Total (Incl. GST): 10600.00
# GST Summary Base Amount
# TX - Standard Rate Purchases (6%) 10000.00 RM —_ 600.00 RM
# For behalf of
#
# SkyGST Sdn, Bhd.
#
# Authorized Signature & Company Chop
#
#
#
#
#
#
#
# Terms & Conditions
#
# All Sales are subject to SkyGST Sdn. Bhd.'s Term and Condition of Sale, Service and Technical Support (“Term and
# Condition"), copies of which are available on www.skygst.com or on request. By submitted an order pursuant to Dallab
# Quotation, you acknowledge that you have read and agree to comply strictly.
#
#
#
# E&OE
#
#
#
# Page: 1/1'
#        label text
# 0  I-address  8th
#        label    text
# 0  I-address     8th
# 1  I-address  Floor,
#        label    text
# 0  I-address     8th
# 1  I-address  Floor,
# 2  I-product   Terms

# %%
for root,dirs,files in os.walk(path):
    for x in files:
        if x.endswith(".csv"):
            print(x)
            f=pd.read_csv(x, delimiter=',')
            f.drop(['Unnamed: 0'],axis=1, inplace=True, index=None)
            f.to_csv(path+"csv/"+x,index=None)
# Out:
# 31.jpg.txt.csv
# 30.pdf.jpg.txt.csv
# 61.jpg.txt.csv
# 32.pdf.jpg.txt.csv
# 31.jpg.txt.csv
# 30.pdf.jpg.txt.csv
# 61.jpg.txt.csv
# 32.pdf.jpg.txt.csv

# %%
def convert_to_json(fname):
    result = []
    rec = {}
    with open(fname) as f:
        for l in f:
            if not l.strip() or l.startswith('label'):
                continue

            if l.startswith(','):
                result.append(rec)
                rec = {}
            else:
                k, v = l.strip().split(',')
                if k.strip():
                    try:
                        rec[k] = int(v)
                    except:
                        rec[k] = v.strip('"')
                else:
                    rec['Comments'] += v.strip('"')
    result.append(rec)
    return result
directory = path+'csv/'
for root,dirs,files in os.walk(directory):
    
    for x in files:
        if x.endswith(".csv"):
        # print(x)
            data=convert_to_json(path+'csv/'+x)
            import json
            with open(path+'json/'+x+'.json', 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=4)


# filepath='/content/a.json'
# with open(filepath,'w')as jsonFile:
#   jsonFile.write(json.dump(data, filepath))
